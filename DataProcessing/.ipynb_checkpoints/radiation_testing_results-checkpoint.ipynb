# %% [markdown]
# # Radiation Testing of the RP2040 and RP2350 Microcontroller Chips

# %% [markdown]
# ## Dynamic Testing
# Tested 2 at a time 3 times
# 1. Pico and Pico 2 (ARM) - Pico pulled first
# 3. Pico 2 (RISC-V) and Pico - ended together
# 4. Pico 2 (ARM) and Pico 2 (RISC-V) - riscv pulled first

# %%
# temp to read given table 

with open("data.txt", "r") as f, open("run_3_data_out.csv", "w") as fout: 
    fout.write("Run#, Rate rad(Si)/s, Dose rad(Si), Duration Time, Measure Dose rad(Si) (+3%), Cumulative Dose rad(Si), Time on, (seconds), \n")
    for line in f:
        parts = line.split()
        for i in range(8):
            parts[i] = "".join(parts[i].split(","))
        if parts[0].isdigit() == False: continue 
        fout.write(",".join(parts[:8]) + "," + " ".join(parts[8:]) + "\n")

# %% [markdown]
# # Static Step Testing
